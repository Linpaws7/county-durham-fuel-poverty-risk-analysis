# %%
import pandas as pd
from pathlib import Path

# %%
PROJECT_ROOT = Path(r"C:\Users\swapn\OneDrive\Desktop\fuel_poverty_risk_england")
RAW_PATH = PROJECT_ROOT / "data" / "raw"
LA_CODE = "E06000047"

# %%
elec_xls = pd.ExcelFile(RAW_PATH / "electricity_la_2005_2024.xlsx")
print(elec_xls.sheet_names)
# Out:
# ['Cover sheet', '2005', '2006', '2007', '2008', '2009', '2010', '2012', '2011', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
elec_test = pd.read_excel(RAW_PATH / "electricity_la_2005_2024.xlsx", sheet_name=0)
elec_test.head(15)
# Out:
#    Subnational electricity consumption, Great Britain, 2005 - 2024
# 0   This workbook presents Accredited Official Sta...
# 1   The electricity consumption years used in thes...
# 2                                            Contents
# 3   Following this Cover sheet this workbook conta...
# 4                                   Publication dates
# 5                  Publication date: 18 December 2025
# 6                          Next update: December 2026
# 7                                           Revisions
# 8   The statistics for the years 2015 onwards are ...
# 9   - Updates to the National Statistics Postcodes...
# 10  - Updates to the meter address information res...
# 11  - Additional information gathered about earlie...
# 12                                        Methodology
# 13  These figures are based on meter level electri...
# 14  Electricity data is divided between domestic a...

# %%
print(elec_xls.sheet_names)
# Out:
# ['Cover sheet', '2005', '2006', '2007', '2008', '2009', '2010', '2012', '2011', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
elec_2024 = pd.read_excel(RAW_PATH / "electricity_la_2005_2024.xlsx", sheet_name="2024")
elec_2024.head(15)
# Out:
#    Subnational electricity consumption, Great Britain, 2024  \
# 0   This table shows the electricity consumption a...
# 1   Some consumption within given countries/region...
# 2   Freeze panes are active on this sheet. To turn...
# 3                                                Code
# 4                                           K03000001
# 5                                           K04000001
# 6                                           E92000001
# 7                                           E12000001
# 8                                           E12000002
# 9                                           E12000003
# 10                                          E12000004
# 11                                          E12000005
# 12                                          E12000006
# 13                                          E12000007
# 14                                          E13000001
#
#                              Unnamed: 1             Unnamed: 2  \
# ...

# %%
elec_2024.columns.tolist()
# Out:
# ['Subnational electricity consumption, Great Britain, 2024',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
elec_2024.head(15)
# Out:
#    Subnational electricity consumption, Great Britain, 2024  \
# 0   This table shows the electricity consumption a...
# 1   Some consumption within given countries/region...
# 2   Freeze panes are active on this sheet. To turn...
# 3                                                Code
# 4                                           K03000001
# 5                                           K04000001
# 6                                           E92000001
# 7                                           E12000001
# 8                                           E12000002
# 9                                           E12000003
# 10                                          E12000004
# 11                                          E12000005
# 12                                          E12000006
# 13                                          E12000007
# 14                                          E13000001
#
#                              Unnamed: 1             Unnamed: 2  \
# ...

# %%
electricity_la = pd.read_excel(
    RAW_PATH / "electricity_la_2005_2024.xlsx",
    sheet_name="2024",
    header=3
)

electricity_la.head()
# Out:
#   Freeze panes are active on this sheet. To turn off freeze panes select the 'View' ribbon then 'Freeze Panes' then 'Unfreeze Panes' or use [Alt W, F].  \
# 0                                               Code
# 1                                          K03000001
# 2                                          K04000001
# 3                                          E92000001
# 4                                          E12000001
#
#                             Unnamed: 1             Unnamed: 2  \
# 0                    Country or region        Local authority
# 1      Great Britain (inc unallocated)  All local authorities
# 2  England and Wales (inc unallocated)  All local authorities
# 3                              England  All local authorities
# 4                           North East  All local authorities
#
#                                           Unnamed: 3  \
# 0  Number of meters\n(thousands):\nDomestic Standard
# 1                                          25859.165
# ...

# %%
electricity_la.columns.tolist()
# Out:
# ["Freeze panes are active on this sheet. To turn off freeze panes select the 'View' ribbon then 'Freeze Panes' then 'Unfreeze Panes' or use [Alt W, F].",
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
pd.read_excel(RAW_PATH / "electricity_la_2005_2024.xlsx", sheet_name="2024", header=None).head(8)
# Out:
#                                                   0   \
# 0  Subnational electricity consumption, Great Bri...
# 1  This table shows the electricity consumption a...
# 2  Some consumption within given countries/region...
# 3  Freeze panes are active on this sheet. To turn...
# 4                                               Code
# 5                                          K03000001
# 6                                          K04000001
# 7                                          E92000001
#
#                                     1                      2   \
# 0                                  NaN                    NaN
# 1                                  NaN                    NaN
# 2                                  NaN                    NaN
# 3                                  NaN                    NaN
# 4                    Country or region        Local authority
# 5      Great Britain (inc unallocated)  All local authorities
# ...

# %%
electricity_la = pd.read_excel(
    RAW_PATH / "electricity_la_2005_2024.xlsx",
    sheet_name="2024",
    header=4
)

electricity_la.head()
# Out:
#         Code                    Country or region        Local authority  \
# 0  K03000001      Great Britain (inc unallocated)  All local authorities
# 1  K04000001  England and Wales (inc unallocated)  All local authorities
# 2  E92000001                              England  All local authorities
# 3  E12000001                           North East  All local authorities
# 4  E12000002                           North West  All local authorities
#
#    Number of meters\n(thousands):\nDomestic Standard  \
# 0                                          25859.165
# 1                                          23364.550
# 2                                          21989.611
# 3                                           1206.275
# 4                                           3162.831
#
#    Number of meters\n(thousands):\nDomestic E7  \
# 0                                     3485.197
# 1                                     3177.150
# 2                                     3093.156
# ...

# %%
electricity_cd = electricity_la[electricity_la["Code"] == LA_CODE].copy()
electricity_cd
# Out:
#          Code Country or region Local authority  \
# 24  E06000047        North East   County Durham
#
#     Number of meters\n(thousands):\nDomestic Standard  \
# 24                                            241.822
#
#     Number of meters\n(thousands):\nDomestic E7  \
# 24                                        6.735
#
#     Number of meters\n(thousands):\nAll Domestic  \
# 24                                       248.557
#
#     Number of meters\n(thousands):\nAll Non-Domestic  \
# 24                                             15.99
#
#     Number of meters\n(thousands):\nAll meters  \
# 24                                     264.547
#
#     Total consumption\n(GWh):\nDomestic Standard  \
# 24                                    665.210853
#
#     Total consumption\n(GWh):\nDomestic E7  ...  \
# 24                               34.216167  ...
#
#     Mean consumption\n(kWh per meter):\nDomestic E7  \
# 24                                      5080.351441
#
# ...

# %%
postcode_join = pd.read_csv(RAW_PATH / f"postcode_epc_fuelpoverty_{LA_CODE}.csv")
postcode_join.head()
# Out:
#   postcode  properties  share_low_rating  share_low_efficiency  \
# 0  DH1 1AF          35          0.114286              0.114286
# 1  DH1 1AH          31          0.129032              0.129032
# 2  DH1 1AL          31          0.096774              0.096774
# 3  DH1 1AQ          22          0.181818              0.181818
# 4  DH1 1AS          36          0.166667              0.166667
#
#    avg_current_efficiency  avg_potential_efficiency  avg_improvement_gap  \
# 0               64.600000                 79.371429            14.771429
# 1               63.000000                 78.709677            15.709677
# 2               63.516129                 79.838710            16.322581
# 3               61.318182                 79.636364            18.318182
# 4               62.222222                 82.666667            20.444444
#
#    risk_score  risk_band  la_fuel_poverty_pct
# 0    0.141080       High                 11.4
# 1    0.156031       High                 11.4
# ...

# %%
postcode_join.columns.tolist(), electricity_cd.columns.tolist()
# Out:
# (['postcode',
#   'properties',
#   'share_low_rating',
#   'share_low_efficiency',
#   'avg_current_efficiency',
#   'avg_potential_efficiency',
#   'avg_improvement_gap',
#   'risk_score',
#   'risk_band',
#   'la_fuel_poverty_pct'],
#  ['Code',
#   'Country or region',
#   'Local authority',
#   'Number of meters\n(thousands):\nDomestic Standard',
#   'Number of meters\n(thousands):\nDomestic E7',
#   'Number of meters\n(thousands):\nAll Domestic',
#   'Number of meters\n(thousands):\nAll Non-Domestic',
#   'Number of meters\n(thousands):\nAll meters',
#   'Total consumption\n(GWh):\nDomestic Standard',
#   'Total consumption\n(GWh):\nDomestic E7',
#   'Total consumption\n(GWh):\nAll Domestic',
#   'Total consumption\n(GWh):\nAll Non-Domestic',
#   'Total consumption\n(GWh):\nAll meters',
#   'Mean consumption\n(kWh per meter):\nDomestic Standard',
#   'Mean consumption\n(kWh per meter):\nDomestic E7',
#   'Mean consumption\n(kWh per meter):\nAll Domestic',
# ...

# %%
postcode_join.columns.tolist(), electricity_cd.columns.tolist()
# Out:
# (['postcode',
#   'properties',
#   'share_low_rating',
#   'share_low_efficiency',
#   'avg_current_efficiency',
#   'avg_potential_efficiency',
#   'avg_improvement_gap',
#   'risk_score',
#   'risk_band',
#   'la_fuel_poverty_pct'],
#  ['Code',
#   'Country or region',
#   'Local authority',
#   'Number of meters\n(thousands):\nDomestic Standard',
#   'Number of meters\n(thousands):\nDomestic E7',
#   'Number of meters\n(thousands):\nAll Domestic',
#   'Number of meters\n(thousands):\nAll Non-Domestic',
#   'Number of meters\n(thousands):\nAll meters',
#   'Total consumption\n(GWh):\nDomestic Standard',
#   'Total consumption\n(GWh):\nDomestic E7',
#   'Total consumption\n(GWh):\nAll Domestic',
#   'Total consumption\n(GWh):\nAll Non-Domestic',
#   'Total consumption\n(GWh):\nAll meters',
#   'Mean consumption\n(kWh per meter):\nDomestic Standard',
#   'Mean consumption\n(kWh per meter):\nDomestic E7',
#   'Mean consumption\n(kWh per meter):\nAll Domestic',
# ...

# %%
postcode_join["la_elec_total_gwh"] = float(electricity_cd["Total consumption\n(GWh):\nAll Domestic"].iloc[0])
postcode_join["la_elec_mean_kwh_per_meter"] = float(electricity_cd["Mean consumption\n(kWh per meter):\nAll Domestic"].iloc[0])
postcode_join["la_mean_domestic_kwh_per_household"] = float(electricity_cd["Mean domestic\nconsumption\n(kWh per household)"].iloc[0])

postcode_join.head()
# Out:
#   postcode  properties  share_low_rating  share_low_efficiency  \
# 0  DH1 1AF          35          0.114286              0.114286
# 1  DH1 1AH          31          0.129032              0.129032
# 2  DH1 1AL          31          0.096774              0.096774
# 3  DH1 1AQ          22          0.181818              0.181818
# 4  DH1 1AS          36          0.166667              0.166667
#
#    avg_current_efficiency  avg_potential_efficiency  avg_improvement_gap  \
# 0               64.600000                 79.371429            14.771429
# 1               63.000000                 78.709677            15.709677
# 2               63.516129                 79.838710            16.322581
# 3               61.318182                 79.636364            18.318182
# 4               62.222222                 82.666667            20.444444
#
#    risk_score  risk_band  la_fuel_poverty_pct  la_elec_total_gwh  \
# 0    0.141080       High                 11.4          699.42702
# ...

# %%
gas_xls = pd.ExcelFile(RAW_PATH / "gas_la_2005_2024.xlsx")
print(gas_xls.sheet_names)
# Out:
# ['Cover sheet', 'Notes', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
gas_2024 = pd.read_excel(RAW_PATH / "gas_la_2005_2024.xlsx", sheet_name="2024", header=4)
gas_2024.head()
# Out:
#   Freeze panes are active on this sheet. To turn off freeze panes select the 'View' ribbon then 'Freeze Panes' then 'Unfreeze Panes' or use [Alt W, F].  \
# 0                                               Code
# 1                                          K03000001
# 2                                          K04000001
# 3                                          E92000001
# 4                                          E12000001
#
#                             Unnamed: 1             Unnamed: 2 Unnamed: 3  \
# 0                    Country or region        Local authority      Notes
# 1      Great Britain (inc unallocated)  All local authorities        NaN
# 2  England and Wales (inc unallocated)  All local authorities        NaN
# 3                              England  All local authorities        NaN
# 4                           North East  All local authorities        NaN
#
#                                    Unnamed: 4  \
# 0  Number of meters\n(thousands):\nDomestic\n
# ...

# %%
gas_2024 = pd.read_excel(RAW_PATH / "gas_la_2005_2024.xlsx", sheet_name="2024", header=5)
gas_2024.head()
# Out:
#         Code                    Country or region        Local authority  \
# 0  K03000001      Great Britain (inc unallocated)  All local authorities
# 1  K04000001  England and Wales (inc unallocated)  All local authorities
# 2  E92000001                              England  All local authorities
# 3  E12000001                           North East  All local authorities
# 4  E12000002                           North West  All local authorities
#
#   Notes  Number of meters\n(thousands):\nDomestic\n  \
# 0   NaN                                   24702.708
# 1   NaN                                   22525.093
# 2   NaN                                   21330.911
# 3   NaN                                    1170.949
# 4   NaN                                    3040.306
#
#    Number of meters\n(thousands):\nNon-Domestic  \
# 0                                       233.229
# 1                                       212.403
# 2                                       202.502
# ...

# %%
gas_cd = gas_2024[gas_2024["Code"] == LA_CODE].copy()
gas_cd
# Out:
#          Code Country or region Local authority Notes  \
# 24  E06000047        North East   County Durham   NaN
#
#     Number of meters\n(thousands):\nDomestic\n  \
# 24                                     234.967
#
#     Number of meters\n(thousands):\nNon-Domestic  \
# 24                                         1.839
#
#     Number of meters\n(thousands):\nAll meters  \
# 24                                     236.806
#
#     Total consumption\n(GWh):\nDomestic\n  \
# 24                            2745.079646
#
#     Total consumption\n(GWh):\nNon-Domestic  \
# 24                              1028.626809
#
#     Total consumption\n(GWh):\nAll meters  \
# 24                            3773.706455
#
#     Mean consumption\n(kWh per meter):\nDomestic\n  \
# 24                                    11682.830549
#
#     Mean consumption\n(kWh per meter):\nNon-Domestic  \
# 24                                     559340.298782
#
#     Mean consumption\n(kWh per meter):\nAll meters  \
# ...

# %%
postcode_join["la_gas_total_gwh"] = float(gas_cd["Total consumption\n(GWh):\nDomestic"].iloc[0])
postcode_join["la_gas_mean_kwh_per_meter"] = float(gas_cd["Mean consumption\n(kWh per meter):\nDomestic"].iloc[0])

postcode_join.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total consumption\n(GWh):\nDomestic'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ...

# %%
gas_cd.columns.tolist()
# Out:
# ['Code',
#  'Country or region',
#  'Local authority',
#  'Notes',
#  'Number of meters\n(thousands):\nDomestic\n',
#  'Number of meters\n(thousands):\nNon-Domestic',
#  'Number of meters\n(thousands):\nAll meters',
#  'Total consumption\n(GWh):\nDomestic\n',
#  'Total consumption\n(GWh):\nNon-Domestic',
#  'Total consumption\n(GWh):\nAll meters',
#  'Mean consumption\n(kWh per meter):\nDomestic\n',
#  'Mean consumption\n(kWh per meter):\nNon-Domestic',
#  'Mean consumption\n(kWh per meter):\nAll meters',
#  'Median consumption\n(kWh per meter):\nDomestic\n',
#  'Median consumption\n(kWh per meter):\nNon-Domestic',
#  'Median consumption\n(kWh per meter):\nAll meters',
#  'Number of \nnon-consuming meters \n(thousands)']

# %%
postcode_join["la_gas_total_gwh"] = float(gas_cd["Total consumption\n(GWh):\nDomestic\n"].iloc[0])
postcode_join["la_gas_mean_kwh_per_meter"] = float(gas_cd["Mean consumption\n(kWh per meter):\nDomestic\n"].iloc[0])

postcode_join.head()
# Out:
#   postcode  properties  share_low_rating  share_low_efficiency  \
# 0  DH1 1AF          35          0.114286              0.114286
# 1  DH1 1AH          31          0.129032              0.129032
# 2  DH1 1AL          31          0.096774              0.096774
# 3  DH1 1AQ          22          0.181818              0.181818
# 4  DH1 1AS          36          0.166667              0.166667
#
#    avg_current_efficiency  avg_potential_efficiency  avg_improvement_gap  \
# 0               64.600000                 79.371429            14.771429
# 1               63.000000                 78.709677            15.709677
# 2               63.516129                 79.838710            16.322581
# 3               61.318182                 79.636364            18.318182
# 4               62.222222                 82.666667            20.444444
#
#    risk_score  risk_band  la_fuel_poverty_pct  la_elec_total_gwh  \
# 0    0.141080       High                 11.4          699.42702
# ...

# %%
iod_xls = pd.ExcelFile(RAW_PATH / "iod2025_la_summary_v2.xlsx")
print(iod_xls.sheet_names)
# Out:
# ['Notes', 'IMD', 'Income', 'Employment', 'Education', 'Health', 'Crime', 'Barriers', 'Living', 'IDACI', 'IDAOPI']

# %%
imd_test = pd.read_excel(RAW_PATH / "iod2025_la_summary_v2.xlsx", sheet_name="IMD")
imd_test.head(15)
# Out:
#    Local Authority District code (2024) Local Authority District name (2024)  \
# 0                             E06000001                           Hartlepool
# 1                             E06000002                        Middlesbrough
# 2                             E06000003                 Redcar and Cleveland
# 3                             E06000004                     Stockton-on-Tees
# 4                             E06000005                           Darlington
# 5                             E06000006                               Halton
# 6                             E06000007                           Warrington
# 7                             E06000008                Blackburn with Darwen
# 8                             E06000009                            Blackpool
# 9                             E06000010          Kingston upon Hull, City of
# 10                            E06000011             East Riding of Yorkshire
# ...

# %%
imd_cd = imd_test[imd_test["Local Authority District code (2024)"] == LA_CODE].copy()
imd_cd
# Out:
#    Local Authority District code (2024) Local Authority District name (2024)  \
# 44                            E06000047                        County Durham
#
#     IMD - Average rank   IMD - Rank of average rank   IMD - Average score   \
# 44             21488.54                           47                28.808
#
#     IMD - Rank of average score   \
# 44                            49
#
#     IMD - Proportion of LSOAs in most deprived 10% nationally   \
# 44                                             0.1697
#
#     IMD - Rank of proportion of LSOAs in most deprived 10% nationally   \
# 44                                                 53
#
#     IMD25 - Extent   IMD25 - Rank of extent   IMD25 - Local concentration   \
# 44           0.3602                       46                      32636.06
#
#     IMD25 - Rank of local concentration
# 44                                    49

# %%
imd_cd.columns.tolist()
# Out:
# ['Local Authority District code (2024)',
#  'Local Authority District name (2024)',
#  'IMD - Average rank ',
#  'IMD - Rank of average rank ',
#  'IMD - Average score ',
#  'IMD - Rank of average score ',
#  'IMD - Proportion of LSOAs in most deprived 10% nationally ',
#  'IMD - Rank of proportion of LSOAs in most deprived 10% nationally ',
#  'IMD25 - Extent ',
#  'IMD25 - Rank of extent ',
#  'IMD25 - Local concentration ',
#  'IMD25 - Rank of local concentration ']

# %%
postcode_join["la_imd_average_rank"] = float(imd_cd["IMD - Average rank "].iloc[0])
postcode_join["la_imd_average_score"] = float(imd_cd["IMD - Average score "].iloc[0])
postcode_join["la_imd_most_deprived_10pct_share"] = float(
    imd_cd["IMD - Proportion of LSOAs in most deprived 10% nationally "].iloc[0]
)

postcode_join.head()
# Out:
#   postcode  properties  share_low_rating  share_low_efficiency  \
# 0  DH1 1AF          35          0.114286              0.114286
# 1  DH1 1AH          31          0.129032              0.129032
# 2  DH1 1AL          31          0.096774              0.096774
# 3  DH1 1AQ          22          0.181818              0.181818
# 4  DH1 1AS          36          0.166667              0.166667
#
#    avg_current_efficiency  avg_potential_efficiency  avg_improvement_gap  \
# 0               64.600000                 79.371429            14.771429
# 1               63.000000                 78.709677            15.709677
# 2               63.516129                 79.838710            16.322581
# 3               61.318182                 79.636364            18.318182
# 4               62.222222                 82.666667            20.444444
#
#    risk_score  risk_band  la_fuel_poverty_pct  la_elec_total_gwh  \
# 0    0.141080       High                 11.4          699.42702
# ...

# %%
final_join_file = RAW_PATH / f"postcode_master_{LA_CODE}.csv"
postcode_join.to_csv(final_join_file, index=False)
print("Saved:", final_join_file)
# Out:
# Saved: C:\Users\swapn\OneDrive\Desktop\fuel_poverty_risk_england\data\raw\postcode_master_E06000047.csv
